# %%
print("hola")
# Out:
# hola

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('pokemon.csv', index_col=0)
df
# Out:
#             Name      Evolution           Type  Total   HP  Attack  Defense  \
# ID
# 0      Bulbasaur                  Grass Poison    318   45      49       49
# 1        Ivysaur                  Grass Poison    405   60      62       63
# 2       Venusaur                  Grass Poison    525   80      82       83
# 3       Venusaur  Mega Venusaur   Grass Poison    625   80     100      123
# 4     Charmander                         Fire     309   39      52       43
# ...          ...            ...            ...    ...  ...     ...      ...
# 1040   Glastrier                          Ice     580  100     145      130
# 1041   Spectrier                        Ghost     580  100      65       60
# 1042     Calyrex                 Psychic Grass    500  100      80       80
# 1043     Calyrex      Ice Rider    Psychic Ice    680  100     165      150
# 1044     Calyrex   Shadow Rider  Psychic Ghost    680  100      85       80
#
# ...

# %%
df.head()
# Out:
#           Name      Evolution          Type  Total  HP  Attack  Defense  \
# ID
# 0    Bulbasaur                 Grass Poison    318  45      49       49
# 1      Ivysaur                 Grass Poison    405  60      62       63
# 2     Venusaur                 Grass Poison    525  80      82       83
# 3     Venusaur  Mega Venusaur  Grass Poison    625  80     100      123
# 4   Charmander                        Fire     309  39      52       43
#
#     Sp.Atk  Sp.Def  Speed  ...                Weight  \
# ID                         ...
# 0       65      65     45  ...     6.9 kg (15.2 lbs)
# 1       80      80     60  ...    13.0 kg (28.7 lbs)
# 2      100     100     80  ...  100.0 kg (220.5 lbs)
# 3      122     120     80  ...  100.0 kg (220.5 lbs)
# 4       60      50     65  ...     8.5 kg (18.7 lbs)
#
#                                   abilities  \
# ID
# 0   1. OvergrowChlorophyll (hidden ability)
# 1   1. OvergrowChlorophyll (hidden ability)
# ...

# %%
df.tail(2)
# Out:
#          Name     Evolution           Type  Total   HP  Attack  Defense  \
# ID
# 1043  Calyrex     Ice Rider    Psychic Ice    680  100     165      150
# 1044  Calyrex  Shadow Rider  Psychic Ghost    680  100      85       80
#
#       Sp.Atk  Sp.Def  Speed  ...             Weight   abilities ev_yield  \
# ID                           ...
# 1043      85     130     50  ...  7.7 kg (17.0 lbs)  1. Unnerve     3 HP
# 1044     165     100    150  ...  7.7 kg (17.0 lbs)  1. Unnerve     3 HP
#
#                            catch_rate           base_friendship  \
# ID
# 1043  3 (0.4% with PokéBall, full HP)  100 (higher than normal)
# 1044  3 (0.4% with PokéBall, full HP)  100 (higher than normal)
#
#      base_experience growth_rate   eggs_groups gender_rate  \
# ID
# 1043             250        Slow  Undiscovered  Genderless
# 1044             250        Slow  Undiscovered  Genderless
#
#                eggs_cycles_rate
# ID
# 1043  120 (30,584–30,840 steps)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1045 entries, 0 to 1044
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              1045 non-null   object
#  1   Evolution         1045 non-null   object
#  2   Type              1045 non-null   object
#  3   Total             1045 non-null   int64
#  4   HP                1045 non-null   int64
#  5   Attack            1045 non-null   int64
#  6   Defense           1045 non-null   int64
#  7   Sp.Atk            1045 non-null   int64
#  8   Sp.Def            1045 non-null   int64
#  9   Speed             1045 non-null   int64
#  10  Species           1045 non-null   object
#  11  Height            1045 non-null   object
#  12  Weight            1045 non-null   object
#  13  abilities         1045 non-null   object
#  14  ev_yield          1045 non-null   object
#  15  catch_rate        1045 non-null   object
# ...

# %%
df.shape
# Out:
# (1045, 22)

# %%
#Manejo de duplicados
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (1045, 22)

# %%
#Manejo de valores vacios
df.isnull()
# Out:
#        Name  Evolution   Type  Total     HP  Attack  Defense  Sp.Atk  Sp.Def  \
# ID
# 0     False      False  False  False  False   False    False   False   False
# 1     False      False  False  False  False   False    False   False   False
# 2     False      False  False  False  False   False    False   False   False
# 3     False      False  False  False  False   False    False   False   False
# 4     False      False  False  False  False   False    False   False   False
# ...     ...        ...    ...    ...    ...     ...      ...     ...     ...
# 1040  False      False  False  False  False   False    False   False   False
# 1041  False      False  False  False  False   False    False   False   False
# 1042  False      False  False  False  False   False    False   False   False
# 1043  False      False  False  False  False   False    False   False   False
# 1044  False      False  False  False  False   False    False   False   False
#
# ...

# %%
#Smar los valores vacios en cada registro
df.isnull().sum()
# Out:
# Name                0
# Evolution           0
# Type                0
# Total               0
# HP                  0
# Attack              0
# Defense             0
# Sp.Atk              0
# Sp.Def              0
# Speed               0
# Species             0
# Height              0
# Weight              0
# abilities           0
# ev_yield            0
# catch_rate          0
# base_friendship     0
# base_experience     0
# growth_rate         0
# eggs_groups         0
# gender_rate         0
# eggs_cycles_rate    0
# dtype: int64

# %%
df2 = df.dropna()

# %%
df2.isnull().sum()
# Out:
# Name                0
# Evolution           0
# Type                0
# Total               0
# HP                  0
# Attack              0
# Defense             0
# Sp.Atk              0
# Sp.Def              0
# Speed               0
# Species             0
# Height              0
# Weight              0
# abilities           0
# ev_yield            0
# catch_rate          0
# base_friendship     0
# base_experience     0
# growth_rate         0
# eggs_groups         0
# gender_rate         0
# eggs_cycles_rate    0
# dtype: int64

# %%
df2.shape
# Out:
# (1045, 22)

# %%
# Guardar el dataframe depurado
df2.to_csv('pokemon_clean.csv', index=False)
