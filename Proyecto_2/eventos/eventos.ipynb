# %%
print("hola")
# Out:
# hola

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('eventos.csv', index_col=0)
df
# Out:
#      Año  Mes          Fecha_inicial             Fecha_final   \
# id
# 1   2015    4  04/20/2015 12:00:00 AM  04/22/2015 12:00:00 AM
# 2   2015    8  08/04/2015 12:00:00 AM  08/13/2015 12:00:00 AM
# 3   2015    9  09/07/2015 12:00:00 AM  09/10/2015 12:00:00 AM
# 4   2015    9  09/17/2015 12:00:00 AM  09/17/2015 12:00:00 AM
# 5   2015    1  01/10/2015 12:00:00 AM  01/10/2015 12:00:00 AM
# ..   ...  ...                     ...                     ...
# 89  2022   11  11/29/2022 12:00:00 AM  11/29/2022 12:00:00 AM
# 90  2023    3  03/05/2023 12:00:00 AM  03/05/2023 12:00:00 AM
# 91  2023    5  05/09/2023 12:00:00 AM  05/09/2023 12:00:00 AM
# 92  2023    5  05/30/2023 12:00:00 AM  05/30/2023 12:00:00 AM
# 93  2023    7  07/26/2023 12:00:00 AM  07/27/2023 12:00:00 AM
#
#                                         Nombre_Evento  \
# id
# 1                             Cartagena Data Festival
# 2   Jornada de datos abiertos para la seguridad ci...
# ...

# %%
df.head()
# Out:
#      Año  Mes          Fecha_inicial             Fecha_final   \
# id
# 1   2015    4  04/20/2015 12:00:00 AM  04/22/2015 12:00:00 AM
# 2   2015    8  08/04/2015 12:00:00 AM  08/13/2015 12:00:00 AM
# 3   2015    9  09/07/2015 12:00:00 AM  09/10/2015 12:00:00 AM
# 4   2015    9  09/17/2015 12:00:00 AM  09/17/2015 12:00:00 AM
# 5   2015    1  01/10/2015 12:00:00 AM  01/10/2015 12:00:00 AM
#
#                                         Nombre_Evento  \
# id
# 1                             Cartagena Data Festival
# 2   Jornada de datos abiertos para la seguridad ci...
# 3                                        Colombia 3.0
# 4                Foro Regional de Líderes de Gobierno
# 5   Presentación de Resultados Diagnostico del Gra...
#
#                                           Descripción  \
# id
# 1   El evento organizado por la ODI, Africa Gather...
# 2   El evento busca generar un espacio para social...
# 3   Comprender la importancia del uso de los datos...
# ...

# %%
df.tail(2)
# Out:
#      Año  Mes          Fecha_inicial             Fecha_final   \
# id
# 92  2023    5  05/30/2023 12:00:00 AM  05/30/2023 12:00:00 AM
# 93  2023    7  07/26/2023 12:00:00 AM  07/27/2023 12:00:00 AM
#
#                                         Nombre_Evento  \
# id
# 92  Desafíos e implicaciones de una gobernanza de ...
# 93   Conmemoración Día Población UNFPA- DANE Colombia
#
#                                           Descripción           Temas  Ciudad  \
# id
# 92  con el objetivo de reconocer el sentido, el fu...  Datos Abiertos  Bogotá
# 93  tema central "Los datos abiertos en un mundo d...  Datos Abiertos  Bogotá
#
#          Lugar                                          Sitio_Web  \
# id
# 92  Presencial  https://twitter.com/jnicobarrios/status/166369...
# 93     Virtual  Link del evento (https://www.youtube.com/watch...
#
#                                               Público           Expositores  \
# id
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 96 entries, 1 to 93
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Año             96 non-null     int64
#  1   Mes             96 non-null     int64
#  2   Fecha_inicial   96 non-null     object
#  3   Fecha_final     96 non-null     object
#  4   Nombre_Evento   96 non-null     object
#  5   Descripción     96 non-null     object
#  6   Temas           96 non-null     object
#  7   Ciudad          96 non-null     object
#  8   Lugar           96 non-null     object
#  9   Sitio_Web       76 non-null     object
#  10  Público         95 non-null     object
#  11  Expositores     96 non-null     object
#  12  Cargo           96 non-null     object
# dtypes: int64(2), object(11)
# memory usage: 10.5+ KB

# %%
df.shape
# Out:
# (96, 13)

# %%
#Manejo de duplicados
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (96, 13)

# %%
#Manejo de valores vacios
df.isnull()
# Out:
#       Año    Mes  Fecha_inicial   Fecha_final   Nombre_Evento  Descripción  \
# id
# 1   False  False           False         False          False        False
# 2   False  False           False         False          False        False
# 3   False  False           False         False          False        False
# 4   False  False           False         False          False        False
# 5   False  False           False         False          False        False
# ..    ...    ...             ...           ...            ...          ...
# 89  False  False           False         False          False        False
# 90  False  False           False         False          False        False
# 91  False  False           False         False          False        False
# 92  False  False           False         False          False        False
# 93  False  False           False         False          False        False
#
# ...

# %%
#Smar los valores vacios en cada registro
df.isnull().sum()
# Out:
# Año                0
# Mes                0
# Fecha_inicial      0
# Fecha_final        0
# Nombre_Evento      0
# Descripción        0
# Temas              0
# Ciudad             0
# Lugar              0
# Sitio_Web         20
# Público            1
# Expositores        0
# Cargo              0
# dtype: int64

# %%
df2 = df.dropna()

# %%
df2.isnull().sum()
# Out:
# Año               0
# Mes               0
# Fecha_inicial     0
# Fecha_final       0
# Nombre_Evento     0
# Descripción       0
# Temas             0
# Ciudad            0
# Lugar             0
# Sitio_Web         0
# Público           0
# Expositores       0
# Cargo             0
# dtype: int64

# %%
df2.shape
# Out:
# (75, 13)

# %%
# Guardar el dataframe depurado
df2.to_csv('eventos_clean.csv', index=False)
