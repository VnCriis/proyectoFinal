# %%
print("hola")
# Out:
# hola

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('videojuegos.csv', index_col=0)
df
# Out:
#                                                    Plataforma   Año  \
# Nombre
# Wii Sports                                                Wii  2006
# Super Mario Bros.                                         NES  1985
# Mario Kart Wii                                            Wii  2008
# Wii Sports Resort                                         Wii  2009
# Pokemon Red/Pokemon Blue                                   GB  1996
# ...                                                       ...   ...
# Farming 2017 - The Simulation                             PS4  2016
# Rugby Challenge 3                                        XOne  2016
# Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shirub...        PSV  2016
# Phantasy Star Online 2 Episode 4: Deluxe Package          PSV  2017
# Brothers Conflict: Precious Baby                          PSV  2017
#
#                                                           Genero  \
# Nombre
# Wii Sports                                                Sports
# ...

# %%
df.head()
# Out:
#                          Plataforma   Año        Genero Editorial  Ventas NA  \
# Nombre
# Wii Sports                      Wii  2006        Sports  Nintendo      41.49
# Super Mario Bros.               NES  1985      Platform  Nintendo      29.08
# Mario Kart Wii                  Wii  2008        Racing  Nintendo      15.85
# Wii Sports Resort               Wii  2009        Sports  Nintendo      15.75
# Pokemon Red/Pokemon Blue         GB  1996  Role-Playing  Nintendo      11.27
#
#                           Ventas EU  Ventas JP  Ventas Otros  Ventas Global
# Nombre
# Wii Sports                    29.02       3.77          8.46          82.74
# Super Mario Bros.              3.58       6.81          0.77          40.24
# Mario Kart Wii                12.88       3.79          3.31          35.82
# Wii Sports Resort             11.01       3.28          2.96          33.00
# Pokemon Red/Pokemon Blue       8.89      10.22          1.00          31.37

# %%
df.tail(2)
# Out:
#                                                  Plataforma   Año  \
# Nombre
# Phantasy Star Online 2 Episode 4: Deluxe Package        PSV  2017
# Brothers Conflict: Precious Baby                        PSV  2017
#
#                                                         Genero     Editorial  \
# Nombre
# Phantasy Star Online 2 Episode 4: Deluxe Package  Role-Playing          Sega
# Brothers Conflict: Precious Baby                        Action  Idea Factory
#
#                                                   Ventas NA  Ventas EU  \
# Nombre
# Phantasy Star Online 2 Episode 4: Deluxe Package        0.0        0.0
# Brothers Conflict: Precious Baby                        0.0        0.0
#
#                                                   Ventas JP  Ventas Otros  \
# Nombre
# Phantasy Star Online 2 Episode 4: Deluxe Package       0.01           0.0
# Brothers Conflict: Precious Baby                       0.01           0.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16326 entries, Wii Sports to Brothers Conflict: Precious Baby
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Plataforma     16326 non-null  object
#  1   Año            16326 non-null  int64
#  2   Genero         16326 non-null  object
#  3   Editorial      16290 non-null  object
#  4   Ventas NA      16326 non-null  float64
#  5   Ventas EU      16326 non-null  float64
#  6   Ventas JP      16326 non-null  float64
#  7   Ventas Otros   16326 non-null  float64
#  8   Ventas Global  16326 non-null  float64
# dtypes: float64(5), int64(1), object(3)
# memory usage: 1.2+ MB

# %%
df.shape
# Out:
# (16326, 9)

# %%
#Manejo de duplicados
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (16071, 9)

# %%
#Manejo de valores vacios
df.isnull()
# Out:
#                                                     Plataforma    Año  Genero  \
# Nombre
# Wii Sports                                               False  False   False
# Super Mario Bros.                                        False  False   False
# Mario Kart Wii                                           False  False   False
# Wii Sports Resort                                        False  False   False
# Pokemon Red/Pokemon Blue                                 False  False   False
# ...                                                        ...    ...     ...
# Farming 2017 - The Simulation                            False  False   False
# Rugby Challenge 3                                        False  False   False
# Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shirub...       False  False   False
# Phantasy Star Online 2 Episode 4: Deluxe Package         False  False   False
# Brothers Conflict: Precious Baby                         False  False   False
#
# ...

# %%
#Smar los valores vacios en cada registro
df.isnull().sum()
# Out:
# Plataforma        0
# Año               0
# Genero            0
# Editorial        33
# Ventas NA         0
# Ventas EU         0
# Ventas JP         0
# Ventas Otros      0
# Ventas Global     0
# dtype: int64

# %%
df2 = df.dropna()

# %%
df2.isnull().sum()
# Out:
# Plataforma       0
# Año              0
# Genero           0
# Editorial        0
# Ventas NA        0
# Ventas EU        0
# Ventas JP        0
# Ventas Otros     0
# Ventas Global    0
# dtype: int64

# %%
df2.shape
# Out:
# (16038, 9)

# %%
# Guardar el dataframe depurado
df2.to_csv('videojuegos_clean.csv', index=False)
