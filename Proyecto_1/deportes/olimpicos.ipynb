# %%
print("hola")
# Out:
# hola

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('olimpicos.csv', index_col=0)
df
# Out:
#                                  Name Sex   Age  Height  Weight  \
# ID
# 1                           A Dijiang   M  24.0   180.0    80.0
# 2                            A Lamusi   M  23.0   170.0    60.0
# 3                 Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 4                Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 5            Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...                               ...  ..   ...     ...     ...
# 35656              Stuart Fitzsimmons   M  19.0     NaN     NaN
# 35656              Stuart Fitzsimmons   M  19.0     NaN     NaN
# 35657  David Thomas "Dave" Fitzsimons   M  26.0   170.0    65.0
# 35657  David Thomas "Dave" Fitzsimons   M  30.0   170.0    65.0
# 35658                    Marek Fiurek   M  23.0   180.0    68.0
#
#                  Team  NOC        Games  Year  Season       City  \
# ID
# 1               China  CHN  1992 Summer  1992  Summer  Barcelona
# ...

# %%
df.head()
# Out:
#                         Name Sex   Age  Height  Weight            Team  NOC  \
# ID
# 1                  A Dijiang   M  24.0   180.0    80.0           China  CHN
# 2                   A Lamusi   M  23.0   170.0    60.0           China  CHN
# 3        Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark  DEN
# 4       Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden  DEN
# 5   Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands  NED
#
#           Games  Year  Season       City          Sport  \
# ID
# 1   1992 Summer  1992  Summer  Barcelona     Basketball
# 2   2012 Summer  2012  Summer     London           Judo
# 3   1920 Summer  1920  Summer  Antwerpen       Football
# 4   1900 Summer  1900  Summer      Paris     Tug-Of-War
# 5   1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                                Event Medal
# ID
# 1        Basketball Men's Basketball   NaN
# 2       Judo Men's Extra-Lightweight   NaN
# ...

# %%
df.tail(2)
# Out:
#                                  Name Sex   Age  Height  Weight  \
# ID
# 35657  David Thomas "Dave" Fitzsimons   M  30.0   170.0    65.0
# 35658                    Marek Fiurek   M  23.0   180.0    68.0
#
#                  Team  NOC        Games  Year  Season    City  \
# ID
# 35657       Australia  AUS  1980 Summer  1980  Summer  Moskva
# 35658  Czech Republic  CZE  1998 Winter  1998  Winter  Nagano
#
#                  Sport                         Event Medal
# ID
# 35657        Athletics  Athletics Men's 5,000 metres   NaN
# 35658  Nordic Combined    Nordic Combined Men's Team   NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 70000 entries, 1 to 35658
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    70000 non-null  object
#  1   Sex     70000 non-null  object
#  2   Age     67268 non-null  float64
#  3   Height  53746 non-null  float64
#  4   Weight  52899 non-null  float64
#  5   Team    70000 non-null  object
#  6   NOC     70000 non-null  object
#  7   Games   70000 non-null  object
#  8   Year    70000 non-null  int64
#  9   Season  70000 non-null  object
#  10  City    70000 non-null  object
#  11  Sport   70000 non-null  object
#  12  Event   70000 non-null  object
#  13  Medal   9690 non-null   object
# dtypes: float64(3), int64(1), object(10)
# memory usage: 8.0+ MB

# %%
df.shape
# Out:
# (70000, 14)

# %%
#Manejo de duplicados
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (69617, 14)

# %%
#Manejo de valores vacios
df.isnull()
# Out:
#         Name    Sex    Age  Height  Weight   Team    NOC  Games   Year  \
# ID
# 1      False  False  False   False   False  False  False  False  False
# 2      False  False  False   False   False  False  False  False  False
# 3      False  False  False    True    True  False  False  False  False
# 4      False  False  False    True    True  False  False  False  False
# 5      False  False  False   False   False  False  False  False  False
# ...      ...    ...    ...     ...     ...    ...    ...    ...    ...
# 35656  False  False  False    True    True  False  False  False  False
# 35656  False  False  False    True    True  False  False  False  False
# 35657  False  False  False   False   False  False  False  False  False
# 35657  False  False  False   False   False  False  False  False  False
# 35658  False  False  False   False   False  False  False  False  False
#
#        Season   City  Sport  Event  Medal
# ID
# 1       False  False  False  False   True
# ...

# %%
#Smar los valores vacios en cada registro
df.isnull().sum()
# Out:
# Name          0
# Sex           0
# Age        2671
# Height    15876
# Weight    16718
# Team          0
# NOC           0
# Games         0
# Year          0
# Season        0
# City          0
# Sport         0
# Event         0
# Medal     59931
# dtype: int64

# %%
df2 = df.dropna()

# %%
df2.isnull().sum()
# Out:
# Name      0
# Sex       0
# Age       0
# Height    0
# Weight    0
# Team      0
# NOC       0
# Games     0
# Year      0
# Season    0
# City      0
# Sport     0
# Event     0
# Medal     0
# dtype: int64

# %%
df2.shape
# Out:
# (7101, 14)

# %%
# Guardar el dataframe depurado
df2.to_csv('olimpicos_clean.csv', index=False)
