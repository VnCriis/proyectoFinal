# %%
print("hola")
# Out:
# hola

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('concerts.csv', index_col=0)
df
# Out:
#                               Location    Time  \
# Date
# 1842-12-07T05:00:00Z     Manhattan, NY  8:00PM
# 1843-02-18T05:00:00Z     Manhattan, NY  8:00PM
# 1843-04-07T05:00:00Z     Manhattan, NY  8:00PM
# 1843-04-22T05:00:00Z     Manhattan, NY  8:00PM
# 1843-11-18T05:00:00Z     Manhattan, NY     NaN
# ...                                ...     ...
# 2017-06-24T04:00:00Z  East Hampton, NY     NaN
# 2017-07-02T04:00:00Z   Shanghai, CHINA  7:30PM
# 2017-07-03T04:00:00Z   Shanghai, CHINA  7:30PM
# 2017-07-04T04:00:00Z   Shanghai, CHINA  7:30PM
# 2017-07-07T04:00:00Z   Shanghai, CHINA  7:30PM
#
#                                                      Venue  \
# Date
# 1842-12-07T05:00:00Z                          Apollo Rooms
# 1843-02-18T05:00:00Z                          Apollo Rooms
# 1843-04-07T05:00:00Z                          Apollo Rooms
# 1843-04-22T05:00:00Z                          Apollo Rooms
# 1843-11-18T05:00:00Z                          Apollo Rooms
# ...                                                    ...
# 2017-06-24T04:00:00Z                            Guild Hall
# 2017-07-02T04:00:00Z                Shanghai Symphony Hall
# 2017-07-03T04:00:00Z                Shanghai Symphony Hall
# 2017-07-04T04:00:00Z  Shanghai Symphony Hall--Chamber Hall
# 2017-07-07T04:00:00Z                Shanghai Symphony Hall
#
#                                           eventType   season  programID  \
# Date
# 1842-12-07T05:00:00Z            Subscription Season  1842-43       3853
# 1843-02-18T05:00:00Z            Subscription Season  1842-43       5178
# 1843-04-07T05:00:00Z                        Special  1842-43      10785
# 1843-04-22T05:00:00Z            Subscription Season  1842-43       5887
# 1843-11-18T05:00:00Z            Subscription Season  1843-44        305
# ...                                             ...      ...        ...
# 2017-06-24T04:00:00Z                        Chamber  2016-17      14189
# 2017-07-02T04:00:00Z                           Tour  2016-17      14146
# 2017-07-03T04:00:00Z                           Tour  2016-17      14148
# 2017-07-04T04:00:00Z  Tour - Young People's Concert  2016-17      14136
# 2017-07-07T04:00:00Z                           Tour  2016-17      14147
#
#                                                      orchestra  \
# Date
# 1842-12-07T05:00:00Z                     New York Philharmonic
# 1843-02-18T05:00:00Z                     New York Philharmonic
# 1843-04-07T05:00:00Z  Musicians from the New York Philharmonic
# 1843-04-22T05:00:00Z                     New York Philharmonic
# 1843-11-18T05:00:00Z                     New York Philharmonic
# ...                                                        ...
# 2017-06-24T04:00:00Z  Musicians from the New York Philharmonic
# 2017-07-02T04:00:00Z                     New York Philharmonic
# 2017-07-03T04:00:00Z                     New York Philharmonic
# 2017-07-04T04:00:00Z                     New York Philharmonic
# 2017-07-07T04:00:00Z                     New York Philharmonic
#
#                                                         id
# Date
# 1842-12-07T05:00:00Z  38e072a7-8fc9-4f9a-8eac-3957905c0002
# 1843-02-18T05:00:00Z  c7b2b95c-5e0b-431c-a340-5b37fc860b34
# 1843-04-07T05:00:00Z  894e1a52-1ae5-4fa7-aec0-b99997555a37
# 1843-04-22T05:00:00Z  34ec2c2b-3297-4716-9831-b538310462b7
# 1843-11-18T05:00:00Z  610a4acc-94e4-4cd6-bdc1-8ad020edc7e9
# ...                                                    ...
# 2017-06-24T04:00:00Z  3d50968c-2e8b-405f-969c-ba36f941f393
# 2017-07-02T04:00:00Z  adb9fc8b-95bc-47d0-9f4b-78fc242f1f8f
# 2017-07-03T04:00:00Z  f072c652-c452-4ad4-975a-f6abd5ff8b4d
# 2017-07-04T04:00:00Z  68625626-8085-44e4-bdb3-d8e6ac51c95b
# 2017-07-07T04:00:00Z  5c22d35f-a282-4505-bd31-df619c74f52b
#
# [21607 rows x 8 columns]

# %%
df.head()
# Out:
#                            Location    Time         Venue  \
# Date
# 1842-12-07T05:00:00Z  Manhattan, NY  8:00PM  Apollo Rooms
# 1843-02-18T05:00:00Z  Manhattan, NY  8:00PM  Apollo Rooms
# 1843-04-07T05:00:00Z  Manhattan, NY  8:00PM  Apollo Rooms
# 1843-04-22T05:00:00Z  Manhattan, NY  8:00PM  Apollo Rooms
# 1843-11-18T05:00:00Z  Manhattan, NY     NaN  Apollo Rooms
#
#                                 eventType   season  programID  \
# Date
# 1842-12-07T05:00:00Z  Subscription Season  1842-43       3853
# 1843-02-18T05:00:00Z  Subscription Season  1842-43       5178
# 1843-04-07T05:00:00Z              Special  1842-43      10785
# 1843-04-22T05:00:00Z  Subscription Season  1842-43       5887
# 1843-11-18T05:00:00Z  Subscription Season  1843-44        305
#
#                                                      orchestra  \
# Date
# 1842-12-07T05:00:00Z                     New York Philharmonic
# 1843-02-18T05:00:00Z                     New York Philharmonic
# 1843-04-07T05:00:00Z  Musicians from the New York Philharmonic
# 1843-04-22T05:00:00Z                     New York Philharmonic
# 1843-11-18T05:00:00Z                     New York Philharmonic
#
#                                                         id
# Date
# 1842-12-07T05:00:00Z  38e072a7-8fc9-4f9a-8eac-3957905c0002
# 1843-02-18T05:00:00Z  c7b2b95c-5e0b-431c-a340-5b37fc860b34
# 1843-04-07T05:00:00Z  894e1a52-1ae5-4fa7-aec0-b99997555a37
# 1843-04-22T05:00:00Z  34ec2c2b-3297-4716-9831-b538310462b7
# 1843-11-18T05:00:00Z  610a4acc-94e4-4cd6-bdc1-8ad020edc7e9

# %%
df.tail(2)
# Out:
#                              Location    Time  \
# Date
# 2017-07-04T04:00:00Z  Shanghai, CHINA  7:30PM
# 2017-07-07T04:00:00Z  Shanghai, CHINA  7:30PM
#
#                                                      Venue  \
# Date
# 2017-07-04T04:00:00Z  Shanghai Symphony Hall--Chamber Hall
# 2017-07-07T04:00:00Z                Shanghai Symphony Hall
#
#                                           eventType   season  programID  \
# Date
# 2017-07-04T04:00:00Z  Tour - Young People's Concert  2016-17      14136
# 2017-07-07T04:00:00Z                           Tour  2016-17      14147
#
#                                   orchestra  \
# Date
# 2017-07-04T04:00:00Z  New York Philharmonic
# 2017-07-07T04:00:00Z  New York Philharmonic
#
#                                                         id
# Date
# 2017-07-04T04:00:00Z  68625626-8085-44e4-bdb3-d8e6ac51c95b
# 2017-07-07T04:00:00Z  5c22d35f-a282-4505-bd31-df619c74f52b

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21607 entries, 1842-12-07T05:00:00Z to 2017-07-07T04:00:00Z
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Location   21588 non-null  object
#  1   Time       20836 non-null  object
#  2   Venue      21552 non-null  object
#  3   eventType  21590 non-null  object
#  4   season     21607 non-null  object
#  5   programID  21607 non-null  int64
#  6   orchestra  21605 non-null  object
#  7   id         21607 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 1.5+ MB

# %%
df.shape
# Out:
# (21607, 8)

# %%
#Manejo de duplicados
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (18831, 8)

# %%
#Manejo de valores vacios
df.isnull()
# Out:
#                       Location   Time  Venue  eventType  season  programID  \
# Date
# 1842-12-07T05:00:00Z     False  False  False      False   False      False
# 1843-02-18T05:00:00Z     False  False  False      False   False      False
# 1843-04-07T05:00:00Z     False  False  False      False   False      False
# 1843-04-22T05:00:00Z     False  False  False      False   False      False
# 1843-11-18T05:00:00Z     False   True  False      False   False      False
# ...                        ...    ...    ...        ...     ...        ...
# 2017-06-24T04:00:00Z     False   True  False      False   False      False
# 2017-07-02T04:00:00Z     False  False  False      False   False      False
# 2017-07-03T04:00:00Z     False  False  False      False   False      False
# 2017-07-04T04:00:00Z     False  False  False      False   False      False
# 2017-07-07T04:00:00Z     False  False  False      False   False      False
#
#                       orchestra     id
# Date
# 1842-12-07T05:00:00Z      False  False
# 1843-02-18T05:00:00Z      False  False
# 1843-04-07T05:00:00Z      False  False
# 1843-04-22T05:00:00Z      False  False
# 1843-11-18T05:00:00Z      False  False
# ...                         ...    ...
# 2017-06-24T04:00:00Z      False  False
# 2017-07-02T04:00:00Z      False  False
# 2017-07-03T04:00:00Z      False  False
# 2017-07-04T04:00:00Z      False  False
# 2017-07-07T04:00:00Z      False  False
#
# [18831 rows x 8 columns]

# %%
#Smar los valores vacios en cada registro
df.isnull().sum()
# Out:
# Location      19
# Time         628
# Venue         55
# eventType     17
# season         0
# programID      0
# orchestra      2
# id             0
# dtype: int64

# %%
df2 = df.dropna()

# %%
df2.isnull().sum()
# Out:
# Location     0
# Time         0
# Venue        0
# eventType    0
# season       0
# programID    0
# orchestra    0
# id           0
# dtype: int64

# %%
df2.shape
# Out:
# (18159, 8)

# %%
# Guardar el dataframe depurado
df2.to_csv('concert_clean.csv', index=False)
