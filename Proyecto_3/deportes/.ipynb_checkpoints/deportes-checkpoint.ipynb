# %%
print("hola")
# Out:
# hola

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('deportes.csv', index_col=0)
df
# Out:
#                                                                         Sports Team  \
# id
# 0                                                              Dallas Cowboys (NFL)
# 1                                                            New York Yankees (MLB)
# 2                                                             New York Knicks (NBA)
# 3                                                                Barcelona (Soccer)
# 4                                                              Real Madrid (Soccer)
# 5, Golden State Warriors (NBA),$4.7 billion,147...                              NaN
# 6, Los Angeles Lakers (NBA),$4.6 billion,70%,"J...                              NaN
# 7                                                        New England Patriots (NFL)
# 8, New York Giants (NFL),$4.3 billion,54%,"John...                              NaN
# 9                                                            Bayern Munich (Soccer)
# ...

# %%
df.head()
# Out:
#                 Sports Team          Value Five-Year Change In Value  \
# id
# 0      Dallas Cowboys (NFL)   $5.7 billion                       43%
# 1    New York Yankees (MLB)  $5.25 billion                       54%
# 2     New York Knicks (NBA)     $5 billion                       67%
# 3        Barcelona (Soccer)  $4.76 billion                       34%
# 4      Real Madrid (Soccer)  $4.75 billion                       30%
#
#                            Owner  Year Purchased      Price Paid
# id
# 0                    Jerry Jones            1989    $150 million
# 1            Steinbrenner family            1973    $8.8 million
# 2   Madison Square Garden Sports            1997    $300 million
# 3                   club members  not applicable  not applicable
# 4                   club members  not applicable  not applicable

# %%
df.tail(2)
# Out:
#                 Sports Team          Value Five-Year Change In Value  \
# id
# 48   Dallas Mavericks (NBA)  $2.45 billion                       75%
# 49   Cleveland Browns (NFL)  $2.35 billion                       57%
#
#                   Owner Year Purchased    Price Paid
# id
# 48           Mark Cuban           2000  $280 million
# 49  ee and Jimmy Haslam           2012  $987 million

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Sports Team                40 non-null     object
#  1   Value                      40 non-null     object
#  2   Five-Year Change In Value  40 non-null     object
#  3   Owner                      40 non-null     object
#  4   Year Purchased             40 non-null     object
#  5   Price Paid                 40 non-null     object
# dtypes: object(6)
# memory usage: 2.7+ KB

# %%
df.shape
# Out:
# (50, 6)

# %%
#Manejo de duplicados
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (41, 6)

# %%
#Manejo de valores vacios
df.isnull()
# Out:
#                                                     Sports Team  Value  \
# id
# 0                                                         False  False
# 1                                                         False  False
# 2                                                         False  False
# 3                                                         False  False
# 4                                                         False  False
# 5, Golden State Warriors (NBA),$4.7 billion,147...         True   True
# 7                                                         False  False
# 9                                                         False  False
# 10                                                        False  False
# 12                                                        False  False
# 13                                                        False  False
# 15                                                        False  False
# ...

# %%
#Smar los valores vacios en cada registro
df.isnull().sum()
# Out:
# Sports Team                  1
# Value                        1
# Five-Year Change In Value    1
# Owner                        1
# Year Purchased               1
# Price Paid                   1
# dtype: int64

# %%
df2 = df.dropna()

# %%
df2.isnull().sum()
# Out:
# Sports Team                  0
# Value                        0
# Five-Year Change In Value    0
# Owner                        0
# Year Purchased               0
# Price Paid                   0
# dtype: int64

# %%
df2.shape
# Out:
# (40, 6)

# %%
# Guardar el dataframe depurado
df2.to_csv('deportes_clean.csv', index=False)
