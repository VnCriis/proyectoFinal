# %%
print("hola")
# Out:
# hola

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('restaurantes.csv', index_col=0)
df
# Out:
#                                          city country  \
# address
# 324 Main St                           Massena      US
# 530 Clinton Ave        Washington Court House      US
# 408 Market Square Dr                Maysville      US
# 6098 State Highway 37                 Massena      US
# 139 Columbus Rd                        Athens      US
# ...                                       ...     ...
# 3013 Peach Orchard Rd                 Augusta      US
# 678 Northwest Hwy                        Cary      US
# 1708 Main St                         Longmont      US
# 67740 Highway 111              Cathedral City      US
# 5701 E La Palma Ave                   Anaheim      US
#
#                                                                     keys  \
# address
# 324 Main St                          us/ny/massena/324mainst/-1161002137
# 530 Clinton Ave        us/oh/washingtoncourthouse/530clintonave/-7914...
# 408 Market Square Dr        us/ky/maysville/408marketsquaredr/1051460804
# 6098 State Highway 37       us/ny/massena/6098statehighway37/-1161002137
# 139 Columbus Rd                     us/oh/athens/139columbusrd/990890980
# ...                                                                  ...
# 3013 Peach Orchard Rd        us/ga/augusta/3013peachorchardrd/-791445730
# 678 Northwest Hwy                   us/il/cary/678northwesthwy/787691191
# 1708 Main St                        us/co/longmont/1708mainst/-448666054
# 67740 Highway 111         us/ca/cathedralcity/67740highway111/-981164808
# 5701 E La Palma Ave              us/ca/anaheim/5701elapalmaave/554191587
#
#                         latitude   longitude                         name  \
# address
# 324 Main St            44.921300  -74.890210                   McDonald's
# 530 Clinton Ave        39.532550  -83.445260                      Wendy's
# 408 Market Square Dr   38.627360  -83.791410             Frisch's Big Boy
# 6098 State Highway 37  44.950080  -74.845530                   McDonald's
# 139 Columbus Rd        39.351550  -82.097280              OMG! Rotisserie
# ...                          ...         ...                          ...
# 3013 Peach Orchard Rd  33.415257  -82.024531                      Wendy's
# 678 Northwest Hwy      42.217300  -88.255800  Lee's Oriental Martial Arts
# 1708 Main St           40.189190 -105.101720                    Five Guys
# 67740 Highway 111      33.788640 -116.482150                El Pollo Loco
# 5701 E La Palma Ave    33.860074 -117.789762                   Carl's Jr.
#
#                       postalCode province  \
# address
# 324 Main St                13662       NY
# 530 Clinton Ave            43160       OH
# 408 Market Square Dr       41056       KY
# 6098 State Highway 37      13662       NY
# 139 Columbus Rd            45701       OH
# ...                          ...      ...
# 3013 Peach Orchard Rd      30906       GA
# 678 Northwest Hwy          60013       IL
# 1708 Main St               80501       CO
# 67740 Highway 111          92234       CA
# 5701 E La Palma Ave        92807       CA
#
#                                                                 websites
# address
# 324 Main St            http://mcdonalds.com,http://www.mcdonalds.com/...
# 530 Clinton Ave                                    http://www.wendys.com
# 408 Market Square Dr   http://www.frischs.com,https://www.frischs.com...
# 6098 State Highway 37  http://mcdonalds.com,http://www.mcdonalds.com/...
# 139 Columbus Rd        http://www.omgrotisserie.com,http://omgrotisse...
# ...                                                                  ...
# 3013 Peach Orchard Rd            http://www.wendys.com,http://wendys.com
# 678 Northwest Hwy                               http://www.mcdonalds.com
# 1708 Main St                                         http://fiveguys.com
# 67740 Highway 111      http://www.elpolloloco.com,http://elpolloloco.com
# 5701 E La Palma Ave                               http://www.carlsjr.com
#
# [10000 rows x 9 columns]

# %%
df.head()
# Out:
#                                          city country  \
# address
# 324 Main St                           Massena      US
# 530 Clinton Ave        Washington Court House      US
# 408 Market Square Dr                Maysville      US
# 6098 State Highway 37                 Massena      US
# 139 Columbus Rd                        Athens      US
#
#                                                                     keys  \
# address
# 324 Main St                          us/ny/massena/324mainst/-1161002137
# 530 Clinton Ave        us/oh/washingtoncourthouse/530clintonave/-7914...
# 408 Market Square Dr        us/ky/maysville/408marketsquaredr/1051460804
# 6098 State Highway 37       us/ny/massena/6098statehighway37/-1161002137
# 139 Columbus Rd                     us/oh/athens/139columbusrd/990890980
#
#                        latitude  longitude              name postalCode  \
# address
# 324 Main St            44.92130  -74.89021        McDonald's      13662
# 530 Clinton Ave        39.53255  -83.44526           Wendy's      43160
# 408 Market Square Dr   38.62736  -83.79141  Frisch's Big Boy      41056
# 6098 State Highway 37  44.95008  -74.84553        McDonald's      13662
# 139 Columbus Rd        39.35155  -82.09728   OMG! Rotisserie      45701
#
#                       province  \
# address
# 324 Main St                 NY
# 530 Clinton Ave             OH
# 408 Market Square Dr        KY
# 6098 State Highway 37       NY
# 139 Columbus Rd             OH
#
#                                                                 websites
# address
# 324 Main St            http://mcdonalds.com,http://www.mcdonalds.com/...
# 530 Clinton Ave                                    http://www.wendys.com
# 408 Market Square Dr   http://www.frischs.com,https://www.frischs.com...
# 6098 State Highway 37  http://mcdonalds.com,http://www.mcdonalds.com/...
# 139 Columbus Rd        http://www.omgrotisserie.com,http://omgrotisse...

# %%
df.tail(2)
# Out:
#                                city country  \
# address
# 67740 Highway 111    Cathedral City      US
# 5701 E La Palma Ave         Anaheim      US
#
#                                                                keys  \
# address
# 67740 Highway 111    us/ca/cathedralcity/67740highway111/-981164808
# 5701 E La Palma Ave         us/ca/anaheim/5701elapalmaave/554191587
#
#                       latitude   longitude           name postalCode province  \
# address
# 67740 Highway 111    33.788640 -116.482150  El Pollo Loco      92234       CA
# 5701 E La Palma Ave  33.860074 -117.789762     Carl's Jr.      92807       CA
#
#                                                               websites
# address
# 67740 Highway 111    http://www.elpolloloco.com,http://elpolloloco.com
# 5701 E La Palma Ave                             http://www.carlsjr.com

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 324 Main St to 5701 E La Palma Ave
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   city        10000 non-null  object
#  1   country     10000 non-null  object
#  2   keys        10000 non-null  object
#  3   latitude    10000 non-null  float64
#  4   longitude   10000 non-null  float64
#  5   name        10000 non-null  object
#  6   postalCode  10000 non-null  object
#  7   province    10000 non-null  object
#  8   websites    10000 non-null  object
# dtypes: float64(2), object(7)
# memory usage: 781.2+ KB

# %%
df.shape
# Out:
# (10000, 9)

# %%
#Manejo de duplicados
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (10000, 9)

# %%
#Manejo de valores vacios
df.isnull()
# Out:
#                         city  country   keys  latitude  longitude   name  \
# address
# 324 Main St            False    False  False     False      False  False
# 530 Clinton Ave        False    False  False     False      False  False
# 408 Market Square Dr   False    False  False     False      False  False
# 6098 State Highway 37  False    False  False     False      False  False
# 139 Columbus Rd        False    False  False     False      False  False
# ...                      ...      ...    ...       ...        ...    ...
# 3013 Peach Orchard Rd  False    False  False     False      False  False
# 678 Northwest Hwy      False    False  False     False      False  False
# 1708 Main St           False    False  False     False      False  False
# 67740 Highway 111      False    False  False     False      False  False
# 5701 E La Palma Ave    False    False  False     False      False  False
#
#                        postalCode  province  websites
# address
# 324 Main St                 False     False     False
# 530 Clinton Ave             False     False     False
# 408 Market Square Dr        False     False     False
# 6098 State Highway 37       False     False     False
# 139 Columbus Rd             False     False     False
# ...                           ...       ...       ...
# 3013 Peach Orchard Rd       False     False     False
# 678 Northwest Hwy           False     False     False
# 1708 Main St                False     False     False
# 67740 Highway 111           False     False     False
# 5701 E La Palma Ave         False     False     False
#
# [10000 rows x 9 columns]

# %%
#Smar los valores vacios en cada registro
df.isnull().sum()
# Out:
# city          0
# country       0
# keys          0
# latitude      0
# longitude     0
# name          0
# postalCode    0
# province      0
# websites      0
# dtype: int64

# %%
df2 = df.dropna()

# %%
df2.isnull().sum()
# Out:
# city          0
# country       0
# keys          0
# latitude      0
# longitude     0
# name          0
# postalCode    0
# province      0
# websites      0
# dtype: int64

# %%
df2.shape
# Out:
# (10000, 9)

# %%
# Guardar el dataframe depurado
df2.to_csv('restaurantes_clean.csv', index=False)
