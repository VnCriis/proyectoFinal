# %%
print("hola")
# Out:
# hola

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('taylor.csv', index_col=0)
df
# Out:
#                         Country                      Venue  \
# City
# Evansville        United States  Roberts Municipal Stadium
# Jonesboro         United States         Convocation Center
# St. Louis         United States           Scottrade Center
# Alexandria        United States  Bishop Ireton High School
# North Charleston  United States  North Charleston Coliseum
# ...                         ...                        ...
# Melbourne             Australia             Marvel Stadium
# Sydney                Australia                ANZ Stadium
# Brisbane              Australia                  The Gabba
# Auckland            New Zealand        Mount Smart Stadium
# Tokyo                     Japan                 Tokyo Dome
#
#                             Opening act(s)   Revenue                     Tour  \
# City
# Evansville        Gloriana\nKellie Pickler    360617            Fearless_Tour
# Jonesboro         Gloriana\nKellie Pickler    340328            Fearless_Tour
# St. Louis         Gloriana\nKellie Pickler    650420            Fearless_Tour
# Alexandria        Gloriana\nKellie Pickler    153303            Fearless_Tour
# North Charleston  Gloriana\nKellie Pickler    398154            Fearless_Tour
# ...                                    ...       ...                      ...
# Melbourne               Charli XCX\nBroods   6755570  Reputation_Stadium_Tour
# Sydney                  Charli XCX\nBroods   7686564  Reputation_Stadium_Tour
# Brisbane                Charli XCX\nBroods   4338127  Reputation_Stadium_Tour
# Auckland                Charli XCX\nBroods   3617593  Reputation_Stadium_Tour
# Tokyo                           Charli XCX  14859847  Reputation_Stadium_Tour
#
#                   Attendance (tickets sold)  Attendance (available)
# City
# Evansville                             7463                    7463
# Jonesboro                              7822                    7822
# St. Louis                             13764                   13764
# Alexandria                            11208                   11208
# North Charleston                       8751                    8751
# ...                                     ...                     ...
# Melbourne                             63027                   63027
# Sydney                                72805                   72805
# Brisbane                              43907                   43907
# Auckland                              35749                   35749
# Tokyo                                100109                  100109
#
# [330 rows x 7 columns]

# %%
df.head()
# Out:
#                         Country                      Venue  \
# City
# Evansville        United States  Roberts Municipal Stadium
# Jonesboro         United States         Convocation Center
# St. Louis         United States           Scottrade Center
# Alexandria        United States  Bishop Ireton High School
# North Charleston  United States  North Charleston Coliseum
#
#                             Opening act(s)  Revenue           Tour  \
# City
# Evansville        Gloriana\nKellie Pickler   360617  Fearless_Tour
# Jonesboro         Gloriana\nKellie Pickler   340328  Fearless_Tour
# St. Louis         Gloriana\nKellie Pickler   650420  Fearless_Tour
# Alexandria        Gloriana\nKellie Pickler   153303  Fearless_Tour
# North Charleston  Gloriana\nKellie Pickler   398154  Fearless_Tour
#
#                   Attendance (tickets sold)  Attendance (available)
# City
# Evansville                             7463                    7463
# Jonesboro                              7822                    7822
# St. Louis                             13764                   13764
# Alexandria                            11208                   11208
# North Charleston                       8751                    8751

# %%
df.tail(2)
# Out:
#               Country                Venue      Opening act(s)   Revenue  \
# City
# Auckland  New Zealand  Mount Smart Stadium  Charli XCX\nBroods   3617593
# Tokyo           Japan           Tokyo Dome          Charli XCX  14859847
#
#                              Tour  Attendance (tickets sold)  \
# City
# Auckland  Reputation_Stadium_Tour                      35749
# Tokyo     Reputation_Stadium_Tour                     100109
#
#           Attendance (available)
# City
# Auckland                   35749
# Tokyo                     100109

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 330 entries, Evansville to Tokyo
# Data columns (total 7 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Country                    330 non-null    object
#  1   Venue                      330 non-null    object
#  2   Opening act(s)             330 non-null    object
#  3   Revenue                    330 non-null    int64
#  4   Tour                       330 non-null    object
#  5   Attendance (tickets sold)  330 non-null    int64
#  6   Attendance (available)     330 non-null    int64
# dtypes: int64(3), object(4)
# memory usage: 20.6+ KB

# %%
df.shape
# Out:
# (330, 7)

# %%
#Manejo de duplicados
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (330, 7)

# %%
#Manejo de valores vacios
df.isnull()
# Out:
#                   Country  Venue  Opening act(s)  Revenue   Tour  \
# City
# Evansville          False  False           False    False  False
# Jonesboro           False  False           False    False  False
# St. Louis           False  False           False    False  False
# Alexandria          False  False           False    False  False
# North Charleston    False  False           False    False  False
# ...                   ...    ...             ...      ...    ...
# Melbourne           False  False           False    False  False
# Sydney              False  False           False    False  False
# Brisbane            False  False           False    False  False
# Auckland            False  False           False    False  False
# Tokyo               False  False           False    False  False
#
#                   Attendance (tickets sold)  Attendance (available)
# City
# Evansville                            False                   False
# Jonesboro                             False                   False
# St. Louis                             False                   False
# Alexandria                            False                   False
# North Charleston                      False                   False
# ...                                     ...                     ...
# Melbourne                             False                   False
# Sydney                                False                   False
# Brisbane                              False                   False
# Auckland                              False                   False
# Tokyo                                 False                   False
#
# [330 rows x 7 columns]

# %%
#Smar los valores vacios en cada registro
df.isnull().sum()
# Out:
# Country                      0
# Venue                        0
# Opening act(s)               0
# Revenue                      0
# Tour                         0
# Attendance (tickets sold)    0
# Attendance (available)       0
# dtype: int64

# %%
df2 = df.dropna()

# %%
df2.isnull().sum()
# Out:
# Country                      0
# Venue                        0
# Opening act(s)               0
# Revenue                      0
# Tour                         0
# Attendance (tickets sold)    0
# Attendance (available)       0
# dtype: int64

# %%
df2.shape
# Out:
# (330, 7)

# %%
# Guardar el dataframe depurado
df2.to_csv('taylor_clean.csv', index=False)
