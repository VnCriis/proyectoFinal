# %%
print("hola")
# Out:
# hola

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('jugadores.csv', index_col=0)
df
# Out:
#             nombre   apellido     nickname codigociudad  total-ganancias  \
# Idjugador
# 3883         Peter  Rasmussen      dupreeh           dk       1822989.41
# 3679       Andreas   Højsleth        Xyp9x           dk       1799288.57
# 3885       Nicolai     Reedtz       dev1ce           dk       1787489.88
# 3672         Lukas  Rossander       gla1ve           dk       1652350.75
# 17800         Emil       Reif       Magisk           dk       1416448.64
# ...            ...        ...          ...          ...              ...
# 7400         Janne   Mikkonen        Savjz           fi         50734.44
# 3255          Drew  Biessener  Tidesoftime           us         50449.60
# 49164       Simone    Liguori         Leta           it         49300.00
# 43043         Mike    Eichner          Ike           us         48550.00
# 1100       Jeffrey      Brusi         SjoW           se         47973.61
#
#                                       juego                 genero
# Idjugador
# 3883       Counter-Strike: Global Offensive   First-Person Shooter
# 3679       Counter-Strike: Global Offensive   First-Person Shooter
# 3885       Counter-Strike: Global Offensive   First-Person Shooter
# 3672       Counter-Strike: Global Offensive   First-Person Shooter
# 17800      Counter-Strike: Global Offensive   First-Person Shooter
# ...                                     ...                    ...
# 7400                            Hearthstone  Collectible Card Game
# 3255                            Hearthstone  Collectible Card Game
# 49164                           Hearthstone  Collectible Card Game
# 43043                           Hearthstone  Collectible Card Game
# 1100                            Hearthstone  Collectible Card Game
#
# [1000 rows x 7 columns]

# %%
df.head()
# Out:
#             nombre   apellido nickname codigociudad  total-ganancias  \
# Idjugador
# 3883         Peter  Rasmussen  dupreeh           dk       1822989.41
# 3679       Andreas   Højsleth    Xyp9x           dk       1799288.57
# 3885       Nicolai     Reedtz   dev1ce           dk       1787489.88
# 3672         Lukas  Rossander   gla1ve           dk       1652350.75
# 17800         Emil       Reif   Magisk           dk       1416448.64
#
#                                       juego                genero
# Idjugador
# 3883       Counter-Strike: Global Offensive  First-Person Shooter
# 3679       Counter-Strike: Global Offensive  First-Person Shooter
# 3885       Counter-Strike: Global Offensive  First-Person Shooter
# 3672       Counter-Strike: Global Offensive  First-Person Shooter
# 17800      Counter-Strike: Global Offensive  First-Person Shooter

# %%
df.tail(2)
# Out:
#             nombre apellido nickname codigociudad  total-ganancias  \
# Idjugador
# 43043         Mike  Eichner      Ike           us         48550.00
# 1100       Jeffrey    Brusi     SjoW           se         47973.61
#
#                  juego                 genero
# Idjugador
# 43043      Hearthstone  Collectible Card Game
# 1100       Hearthstone  Collectible Card Game

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 3883 to 1100
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   nombre           1000 non-null   object
#  1   apellido         1000 non-null   object
#  2   nickname         1000 non-null   object
#  3   codigociudad     1000 non-null   object
#  4   total-ganancias  1000 non-null   float64
#  5   juego            1000 non-null   object
#  6   genero           1000 non-null   object
# dtypes: float64(1), object(6)
# memory usage: 62.5+ KB

# %%
df.shape
# Out:
# (1000, 7)

# %%
#Manejo de duplicados
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (1000, 7)

# %%
#Manejo de valores vacios
df.isnull()
# Out:
#            nombre  apellido  nickname  codigociudad  total-ganancias  juego  \
# Idjugador
# 3883        False     False     False         False            False  False
# 3679        False     False     False         False            False  False
# 3885        False     False     False         False            False  False
# 3672        False     False     False         False            False  False
# 17800       False     False     False         False            False  False
# ...           ...       ...       ...           ...              ...    ...
# 7400        False     False     False         False            False  False
# 3255        False     False     False         False            False  False
# 49164       False     False     False         False            False  False
# 43043       False     False     False         False            False  False
# 1100        False     False     False         False            False  False
#
#            genero
# Idjugador
# 3883        False
# 3679        False
# 3885        False
# 3672        False
# 17800       False
# ...           ...
# 7400        False
# 3255        False
# 49164       False
# 43043       False
# 1100        False
#
# [1000 rows x 7 columns]

# %%
#Smar los valores vacios en cada registro
df.isnull().sum()
# Out:
# nombre             0
# apellido           0
# nickname           0
# codigociudad       0
# total-ganancias    0
# juego              0
# genero             0
# dtype: int64

# %%
df2 = df.dropna()

# %%
df2.isnull().sum()
# Out:
# nombre             0
# apellido           0
# nickname           0
# codigociudad       0
# total-ganancias    0
# juego              0
# genero             0
# dtype: int64

# %%
df2.shape
# Out:
# (1000, 7)

# %%
# Guardar el dataframe depurado
df2.to_csv('jugadores_clean.csv', index=False)
