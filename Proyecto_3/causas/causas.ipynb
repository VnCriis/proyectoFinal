# %%
print("hola")
# Out:
# hola

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('causas.csv', index_col=0)
df
# Out:
#                   Code  Year  Meningitis  \
# Country/Territory
# Afghanistan        AFG  1990        2159
# Afghanistan        AFG  1991        2218
# Afghanistan        AFG  1992        2475
# Afghanistan        AFG  1993        2812
# Afghanistan        AFG  1994        3027
# ...                ...   ...         ...
# Zimbabwe           ZWE  2015        1439
# Zimbabwe           ZWE  2016        1457
# Zimbabwe           ZWE  2017        1460
# Zimbabwe           ZWE  2018        1450
# Zimbabwe           ZWE  2019        1450
#
#                    Alzheimer's Disease and Other Dementias  \
# Country/Territory
# Afghanistan                                           1116
# Afghanistan                                           1136
# Afghanistan                                           1162
# Afghanistan                                           1187
# Afghanistan                                           1211
# ...                                                    ...
# ...

# %%
df.head()
# Out:
#                   Code  Year  Meningitis  \
# Country/Territory
# Afghanistan        AFG  1990        2159
# Afghanistan        AFG  1991        2218
# Afghanistan        AFG  1992        2475
# Afghanistan        AFG  1993        2812
# Afghanistan        AFG  1994        3027
#
#                    Alzheimer's Disease and Other Dementias  \
# Country/Territory
# Afghanistan                                           1116
# Afghanistan                                           1136
# Afghanistan                                           1162
# Afghanistan                                           1187
# Afghanistan                                           1211
#
#                    Parkinson's Disease  Nutritional Deficiencies  Malaria  \
# Country/Territory
# Afghanistan                        371                      2087       93
# Afghanistan                        374                      2153      189
# ...

# %%
df.tail(2)
# Out:
#                   Code  Year  Meningitis  \
# Country/Territory
# Zimbabwe           ZWE  2018        1450
# Zimbabwe           ZWE  2019        1450
#
#                    Alzheimer's Disease and Other Dementias  \
# Country/Territory
# Zimbabwe                                               795
# Zimbabwe                                               812
#
#                    Parkinson's Disease  Nutritional Deficiencies  Malaria  \
# Country/Territory
# Zimbabwe                           227                      2918     2088
# Zimbabwe                           232                      2884     2068
#
#                    Drowning  Interpersonal Violence  Maternal Disorders  ...  \
# Country/Territory                                                        ...
# Zimbabwe                825                    1396                1294  ...
# Zimbabwe                827                    1434                1294  ...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6120 entries, Afghanistan to Zimbabwe
# Data columns (total 33 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Code                                        6120 non-null   object
#  1   Year                                        6120 non-null   int64
#  2   Meningitis                                  6120 non-null   int64
#  3   Alzheimer's Disease and Other Dementias     6120 non-null   int64
#  4   Parkinson's Disease                         6120 non-null   int64
#  5   Nutritional Deficiencies                    6120 non-null   int64
#  6   Malaria                                     6120 non-null   int64
#  7   Drowning                                    6120 non-null   int64
#  8   Interpersonal Violence                      6120 non-null   int64
#  9   Maternal Disorders                          6120 non-null   int64
# ...

# %%
df.shape
# Out:
# (6120, 33)

# %%
#Manejo de duplicados
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (6120, 33)

# %%
#Manejo de valores vacios
df.isnull()
# Out:
#                     Code   Year  Meningitis  \
# Country/Territory
# Afghanistan        False  False       False
# Afghanistan        False  False       False
# Afghanistan        False  False       False
# Afghanistan        False  False       False
# Afghanistan        False  False       False
# ...                  ...    ...         ...
# Zimbabwe           False  False       False
# Zimbabwe           False  False       False
# Zimbabwe           False  False       False
# Zimbabwe           False  False       False
# Zimbabwe           False  False       False
#
#                    Alzheimer's Disease and Other Dementias  \
# Country/Territory
# Afghanistan                                          False
# Afghanistan                                          False
# Afghanistan                                          False
# Afghanistan                                          False
# Afghanistan                                          False
# ...

# %%
#Smar los valores vacios en cada registro
df.isnull().sum()
# Out:
# Code                                          0
# Year                                          0
# Meningitis                                    0
# Alzheimer's Disease and Other Dementias       0
# Parkinson's Disease                           0
# Nutritional Deficiencies                      0
# Malaria                                       0
# Drowning                                      0
# Interpersonal Violence                        0
# Maternal Disorders                            0
# HIV/AIDS                                      0
# Drug Use Disorders                            0
# Tuberculosis                                  0
# Cardiovascular Diseases                       0
# Lower Respiratory Infections                  0
# Neonatal Disorders                            0
# Alcohol Use Disorders                         0
# Self-harm                                     0
# Exposure to Forces of Nature                  0
# Diarrheal Diseases                            0
# ...

# %%
df2 = df.dropna()

# %%
df2.isnull().sum()
# Out:
# Code                                          0
# Year                                          0
# Meningitis                                    0
# Alzheimer's Disease and Other Dementias       0
# Parkinson's Disease                           0
# Nutritional Deficiencies                      0
# Malaria                                       0
# Drowning                                      0
# Interpersonal Violence                        0
# Maternal Disorders                            0
# HIV/AIDS                                      0
# Drug Use Disorders                            0
# Tuberculosis                                  0
# Cardiovascular Diseases                       0
# Lower Respiratory Infections                  0
# Neonatal Disorders                            0
# Alcohol Use Disorders                         0
# Self-harm                                     0
# Exposure to Forces of Nature                  0
# Diarrheal Diseases                            0
# ...

# %%
df2.shape
# Out:
# (6120, 33)

# %%
# Guardar el dataframe depurado
df2.to_csv('causas_clean.csv', index=False)
